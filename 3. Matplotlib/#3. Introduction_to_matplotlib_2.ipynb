# %% [markdown]
# ## Scatter & Bar Plot
# ### Making figures with Numpy arrays
# * `Line plot`
# * `Scatter plot`
# * `Bar plot`
# * `Histogram`
# * `Subplots`

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %% [markdown]
# ### Line plot - sơ đồ đường

# %%
#plot the data & create a line plot
fig, ax = plt.subplots(figsize = (4,5))
ax.plot(x, x**2);

# %% [markdown]
# ### Scatter - sơ đồ phân tán, rải rác

# %%
fig, ax = plt.subplots(figsize = (6,4))
ax.scatter(x, np.exp(x));

# %%
fig, ax = plt.subplots(figsize = (6,4))
ax.scatter(x, np.sin(x));

# %%
fig, ax = plt.subplots(figsize = (6,4))
ax.scatter(x, np.cos(x));

# %% [markdown]
# ### Bar - sơ đồ cột
# * Vertical - Thẳng đứng
# * Horizontal -
# Nằm ngan

# %%
# Make a plot from dictionary
# You can make plots from a dictionary
nut_butter_prices = {'Almod butter':21,
                     'Peanut better':14,
                     'Cashew butter':18}
fig,ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title='Dans Nut Butter Store', ylabel = 'Prices ($)');

# %%
fig, ax = plt.subplots(figsize=(6,4))
#print(nut_butter_prices.keys()) : need to list (keys & values) before providing to barh() function 
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %% [markdown]
# ### Histogram (Hist) - biểu đồ tần suất
# * Could show image of normal dist here

# %%
# Make some data from a normal distribution
x = np.random.randn(1000) # pulls data from a normal distribution

fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Subplots
# Two options for subplots

# %%
# Option 1: Create multiple subplots
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, 
                                             ncols=2, 
                                             figsize=(10, 5))

# Plot data to each axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Option 2: 
fig, ax = plt.subplots(nrows = 2, 
                       ncols = 2,
                       figsize=(10,5))
# Plot data to each index
ax[0,0].plot(x, x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));
